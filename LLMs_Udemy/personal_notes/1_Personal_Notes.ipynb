# %%
# ! pip install langchain
# ! pip install langchain-community langchain-core
# ! pip install Openai

# %%
import os
os.environ['OPENAI_API_KEY'] = ''

# %%
from langchain.llms import OpenAI

# %%
llm = OpenAI(model='gpt-3.5-turbo-instruct')

# %%
our_query = """What's the meaning of the expression 万人に好かれるわけではない in japanese?"""
completion = llm(our_query)

# %%
print(completion)
# Out:
# The expression 万人に好かれるわけではない (banjin ni sukareru wake dewa nai) means "It's not possible to be liked by everyone" or "Not everyone will like you". It implies that no matter how likable or agreeable a person may be, there will always be some people who do not like them.

# %% [markdown]
# # Hugging Face

# %%
# ! pip install huggingface_hub

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = ''

# %%
from langchain.llms import HuggingFaceEndpoint

# %%
llm = HuggingFaceHub(repo_id = 'google/flan-t5-large')

# %%
our_query = """What's the currency in Brazil?"""
completion = llm.invoke(our_query)

# %%
print(completion)
# Out:
# brazilian real

# %% [markdown]
# # Google Gemini (無料！)

# %%
# ! pip install langchain-google-genai

# %%
import os
os.environ['GOOGLE_API_KEY'] = ''

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-pro")
completion = llm.invoke("Sing a ballad of blockchain but in Portuguese and using the characters of Turma da Mônica.")

# %%
print(completion.content)
# Out:
# **Célia, Cebolinha e Cascão no Mundo Blockchain**
#
# (Verso 1)
# No mundo virtual, onde dados são a lei,
# Uma nova era surge, blockchain é o rei.
# Célia, a esperta, Cebolinha, o inventor,
# E Cascão, o sujinho, entram nessa evolução.
#
# (Refrão)
# Célia, Cebolinha, Cascão,
# No blockchain, uma nova canção.
# Transações seguras, sem intermediário,
# Um mundo descentralizado, revolucionário.
#
# (Verso 2)
# Célia, com sua astúcia, cria contratos inteligentes,
# Autoexecutáveis, transparentes e eficientes.
# Cebolinha, com sua engenhosidade,
# Desenvolve aplicativos, com agilidade e criatividade.
#
# (Verso 3)
# Cascão, apesar da sujeira,
# Entende o valor da blockchain, uma nova era.
# Armazena seus dados com segurança e privacidade,
# Protegendo-os da invasão e da maldade.
#
# (Refrão)
# Célia, Cebolinha, Cascão,
# No blockchain, uma nova canção.
# Transações seguras, sem intermediário,
# Um mundo descentralizado, revolucionário.
#
# (Ponte)
# ...
